# %%
import cv2
from cv2 import dnn_superres
import matplotlib.pyplot as plt

# Create an SR object
sr = dnn_superres.DnnSuperResImpl_create()

# Read image
image = cv2.imread(r'train\0001\0001_002.bmp')
plt.imshow(image)
# Read the desired model
path = "FSRCNN-small_x3.pb"
sr.readModel(path)

# Set the desired model and scale to get correct pre- and post-processing
sr.setModel("fsrcnn", 3)

# Upscale the image
result = sr.upsample(image)

# Save the image
cv2.imwrite("./upscaled.png", result)
# Out:
# True

# %%
image2 = cv2.imread('upscaled.png')
plt.imshow(image2)

# %%
img = cv2.imread("train/0029/0029_002.bmp")
plt.imshow(img)
result = sr.upsample(img)
plt.imshow(result)

# %%
plt.imshow(img)

# %%
import numpy as np
img = cv2.imread("upscale_test.jpg")
plt.imshow(img)
result = sr.upsample(img)
plt.imshow(result)

k = np.array([[0,-1,0],
              [-1,5,-1],
              [0,-1,0]], dtype=np.float64)

result = cv2.filter2D(result, -1, k)
cv2.imwrite("upscaled_test.jpg", result)
# Out:
# True
